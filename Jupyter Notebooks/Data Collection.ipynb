# %% [markdown]
# # Data Collection
#
# ## Import Packages

# %%
from bs4 import BeautifulSoup
import requests
import json
import time
import pandas as pd
import numpy as np
import threading

# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Web Scrape Functions
#
# Our first function will have us finding information on census.gov for given cities and storing this into several different lists.
#
# information to a dataframe.

# %%
df_dict = {'CITY': [], #city
           'STATE': [], #state
           'PA': [], #political affiliation
           'POP': [], #population
           'UNDER_5': [], #% of people under age 5
           'UNDER_18': [], #% of people under age 18
           '65_OR_OVER': [], #% of people 65 and older
           'FEMALE': [], #% female
          'WHITE': [], #% white only
          'BLACK': [], #% black only
          'AMERICAN_INDIAN': [], #% american indian or alaska native only
          'ASIAN': [], #% asian only
           'PACIFIC_ISLANDER': [], #% native hawaiian and other pacific islander only
          'MULTI_RACE': [], #% two+ races
          'HISPANIC': [], #% hispanic
          'VETERAN': [], #num of veterans
          'FOREIGN': [], #% foreign born
          'HOUSES': [], #% of owner occupied houses
          'HOUSE_VAL': [], #median value of owner occupied houses
          'RENT': [], #median gross rent
          'HOUSEHOLDS': [], #households
          'PPH': [], #people per household
          'YEAR_IN_HOUSE': [], #% of people living in same house for one year or more
          'OTHER_HOME_LANG': [], #% of people, 5+ years old, who speak a language other than english at home
          'COMPUTER': [], #% of households with computer
          'INTERNET': [], #% of households with internet
          'HIGH_SCHOOL': [], #% of people, 25+ years old, with high school diploma or higher 
          'BACH_DEGREE': [], #% of people, 25+ years old, with bachelor's degree or higher
          'DISABILITY_UNDER_65': [], #% of people with a disability under 65 years old
          'NO_INSURANCE': [], #% of people without health insurance, under 65 years old
          'LABOR': [], #% of population in civilian labor force, 16+ years old
          'FEM_LABOR': [], #% of female population in civilian labor force, 16+ years old
          'HEALTHCARE': [], #healthcare and social assistance revenue ($1,000)
          'SHIPMENTS': [], #manufacturers shipments ($1,000)
          'TRAVEL_TIME': [], #average travel time to work (min), 16+ years old
          'HOUSEHOLD_INCOME': [], #average household income
          'INCOME': [], #per capita income in last 12 months
          'POVERTY': [], #% of people in poverty
          'FIRMS': [], #all firms
          'MEN_FIRM': [], #men owned firms
          'FEM_FIRM': [], #female owned firms
          'MINOR_FIRM': [], #minority owned firms
          'NON_MINOR_FIRM': [], #nonminority owned firms
          'VET_FIRM': [], #veteran owned firms
          'NON_VET_FIRM': [], #non-veteran owned firms
          'POP_AREA': [], #population per square mile
          'AREA': [] #land area in square miles
          }

# %%
def collect_city_data(city, state):
    banana = False
    """Collect census and political affiliation data for given city and append it to data dictionary."""
    #append city and state data to df dictionary
    # change city and state variables into format for census url
    census_city = city.lower().strip().replace(" ", "")
    census_state = state.lower().strip().replace(" ", "")
    # change city and state variables into format for political affiliation url
    aff_city = city.lower().replace(" ", "_")
    aff_state = state.lower().replace(" ", "_")
    try:
        #navigate to census page for this particular city
        census_url = f"https://www.census.gov/quickfacts/fact/table/{census_city}city{census_state}/PST045219"
        html_page = requests.get(census_url)
        html_tree = BeautifulSoup(html_page.content, 'html.parser')
        facts_container = html_tree.find('div', class_="qf-facttable")
        #if page times out, we try again
        while facts_container is None:
            time.sleep(1)
            census_url = f"https://www.census.gov/quickfacts/fact/table/{census_city}city{census_state}/PST045219"
            html_page = requests.get(census_url)
            html_tree = BeautifulSoup(html_page.content, 'html.parser')
            facts_container = html_tree.find('div', class_="qf-facttable")
        #pages not found on census website will redirect to USA facts page
        name_found = html_tree.find('div', class_="qf-geobox").find('span').get_text()
        #if this happens, raise an exception
        if name_found == 'United States':
            #print("Appending PA with NaN")
            df_dict['CITY'].append(city)
            df_dict['STATE'].append(state)
            df_dict['PA'].append("NaN")
            #print("I did it")
            raise ValueError("City Not Found")
            #print("You should never see me... john cena")
        #grab information for each row
        #population
        #if banana:
            #print("You should also never see me!")
        population_facts = facts_container.findAll('tbody')[1]
        population = population_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people under age 5
        age_and_sex_facts = facts_container.findAll('tbody')[2]
        person_under_5 = age_and_sex_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% of people under age 18
        person_under_18 = age_and_sex_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people 65 and older
        person_65_plus = age_and_sex_facts.findAll('tr')[3].findAll('td')[1].attrs['data-value']
        #% female
        female = age_and_sex_facts.findAll('tr')[4].findAll('td')[1].attrs['data-value']
        #% white only
        race_facts = facts_container.findAll('tbody')[3]
        white = race_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% black only
        black = race_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% american indian or alaska native only
        american_indian_or_alaska_native = race_facts.findAll('tr')[3].findAll('td')[1].attrs['data-value']
        #% asian only
        asian = race_facts.findAll('tr')[4].findAll('td')[1].attrs['data-value']
        #% native hawaiian and other pacific islander only
        native_hawaiian_and_other_pacific_islander = race_facts.findAll('tr')[5].findAll('td')[1].attrs['data-value']
        #% two+ races
        two_or_more_races = race_facts.findAll('tr')[6].findAll('td')[1].attrs['data-value']
        #% hispanic
        hispanic = race_facts.findAll('tr')[7].findAll('td')[1].attrs['data-value']
        #num of veterans
        pop_characteristic_facts = facts_container.findAll('tbody')[4]
        veteran = pop_characteristic_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% foreign born
        foreign_born = pop_characteristic_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of owner occupied houses
        housing_facts = facts_container.findAll('tbody')[5]
        owner_occupied_houses = housing_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #median value of owner occupied houses
        median_value_owner_occupied_houses = housing_facts.findAll('tr')[3].findAll('td')[1].attrs['data-value']
        #median gross rent
        median_rent = housing_facts.findAll('tr')[6].findAll('td')[1].attrs['data-value']
        #households
        family_facts = facts_container.findAll('tbody')[6]
        households = family_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #people per household
        people_per_household = family_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people living in same house for one year or more
        same_house_oneplus_years = family_facts.findAll('tr')[3].findAll('td')[1].attrs['data-value']
        #% of people, 5+ years old, who speak a language other than english at home
        non_english_house = family_facts.findAll('tr')[4].findAll('td')[1].attrs['data-value']
        #% of households with computer
        computer_facts = facts_container.findAll('tbody')[7]
        household_w_computer = computer_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% of households with internet
        household_w_internet = computer_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people, 25+ years old, with high school diploma or higher
        education_facts = facts_container.findAll('tbody')[8]
        highschoolplus_25plus = education_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% of people, 25+ years old, with bachelor's degree or higher
        bachelorsplus_25plus = education_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people with a disability under 65 years old
        health_facts = facts_container.findAll('tbody')[9]
        disability_65under = health_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% of people without health insurance, under 65 years old
        no_healthinsurance_65under = health_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of population in civilian labor force, 16+ years old
        economy_facts = facts_container.findAll('tbody')[10]
        total_laborforce_16plus = economy_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #% of female population in civilian labor force, 16+ years old
        female_laborforce_16plus = economy_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #healthcare and social assistance revenue ($1,000)
        healthcare_socialassistance_x1000 = economy_facts.findAll('tr')[4].findAll('td')[1].attrs['data-value']
        #manufacturers shipments ($1,000)
        manufacturer_shipments_x1000 = economy_facts.findAll('tr')[5].findAll('td')[1].attrs['data-value']
        #average travel time to work (min), 16+ years old
        transportation_facts = facts_container.findAll('tbody')[11]
        avg_travel_time_work_16plus = transportation_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #average household income
        income_poverty_facts = facts_container.findAll('tbody')[12]
        median_household_income = income_poverty_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #per capita income in last 12 months
        per_capita_income_12mo = income_poverty_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #% of people in poverty
        people_in_poverty = income_poverty_facts.findAll('tr')[3].findAll('td')[1].attrs['data-value']
        #all firms
        business_facts = facts_container.findAll('tbody')[13]
        all_firms = business_facts.findAll('tr')[6].findAll('td')[1].attrs['data-value']
        #men owned firms
        men_owned_firms = business_facts.findAll('tr')[7].findAll('td')[1].attrs['data-value']
        #female owned firms
        women_owned_firms = business_facts.findAll('tr')[8].findAll('td')[1].attrs['data-value']
        #minority owned firms
        minority_owned_firms = business_facts.findAll('tr')[9].findAll('td')[1].attrs['data-value']
        #nonminority owned firms
        non_minority_owned_firms = business_facts.findAll('tr')[10].findAll('td')[1].attrs['data-value']
        #veteran owned firms
        veteran_owned_firms = business_facts.findAll('tr')[11].findAll('td')[1].attrs['data-value']
        #non-veteran owned firms
        non_veteran_owned_firms = business_facts.findAll('tr')[12].findAll('td')[1].attrs['data-value']
        #population per square mile
        geography_facts = facts_container.findAll('tbody')[14]
        population_per_sq_mile = geography_facts.findAll('tr')[1].findAll('td')[1].attrs['data-value']
        #land area in square miles
        land_in_sq_miles = geography_facts.findAll('tr')[2].findAll('td')[1].attrs['data-value']
        #navigate to bestplaces page for this particular city
        try:
            aff_url = f"https://www.bestplaces.net/voting/city/{aff_state}/{aff_city}"
            html_page = requests.get(aff_url)
            if "404" in html_page.url:
                raise requests.HTTPError()
            html_tree = BeautifulSoup(html_page.content, 'html.parser')
            container = html_tree.find_all('div', class_='col-md-12')
            while container is None:
                time.sleep(1)
                aff_url = f"https://www.bestplaces.net/voting/city/{aff_state}/{aff_city}"
                html_page = requests.get(aff_url)
                if "404" in html_page.url:
                    raise requests.HTTPError()
                html_tree = BeautifulSoup(html_page.content, 'html.parser')
                container = html_tree.find_all('div', class_='col-md-12')
            affiliation = container[1].find('b').text
            bad_chars = ['.', ','] 
            for i in bad_chars : 
                affiliation = affiliation.replace(i, '')
            affiliation = affiliation.split(' is ')[1].lower().split(' ')[1]
        except Exception as e:
            affiliation = "NaN"
            if e.__class__.__name__ == "HTTPError":
                print(f"{city} page not found in bestplaces.")
            else:
                print(f"An unexpected error occurred processing PA for {city}. Error: {e}")
        # append all collected data to the df dictionary
        df_dict['CITY'].append(city)
        df_dict['STATE'].append(state)
        df_dict['PA'].append(affiliation)
        df_dict['POP'].append(population)
        df_dict['UNDER_5'].append(person_under_5)
        df_dict['UNDER_18'].append(person_under_18)
        df_dict['65_OR_OVER'].append(person_65_plus)
        df_dict['FEMALE'].append(female)
        df_dict['WHITE'].append(white)
        df_dict['BLACK'].append(black)
        df_dict['AMERICAN_INDIAN'].append(american_indian_or_alaska_native)
        df_dict['ASIAN'].append(asian)
        df_dict['PACIFIC_ISLANDER'].append(native_hawaiian_and_other_pacific_islander)
        df_dict['MULTI_RACE'].append(two_or_more_races)
        df_dict['HISPANIC'].append(hispanic)
        df_dict['VETERAN'].append(veteran)
        df_dict['FOREIGN'].append(foreign_born)
        df_dict['HOUSES'].append(owner_occupied_houses)
        df_dict['HOUSE_VAL'].append(median_value_owner_occupied_houses)
        df_dict['RENT'].append(median_rent)
        df_dict['HOUSEHOLDS'].append(households)
        df_dict['PPH'].append(people_per_household)
        df_dict['YEAR_IN_HOUSE'].append(same_house_oneplus_years)
        df_dict['OTHER_HOME_LANG'].append(non_english_house)
        df_dict['COMPUTER'].append(household_w_computer)
        df_dict['INTERNET'].append(household_w_internet)
        df_dict['HIGH_SCHOOL'].append(highschoolplus_25plus)
        df_dict['BACH_DEGREE'].append(bachelorsplus_25plus)
        df_dict['DISABILITY_UNDER_65'].append(disability_65under)
        df_dict['NO_INSURANCE'].append(no_healthinsurance_65under)
        df_dict['LABOR'].append(total_laborforce_16plus)
        df_dict['FEM_LABOR'].append(female_laborforce_16plus)
        df_dict['HEALTHCARE'].append(healthcare_socialassistance_x1000)
        df_dict['SHIPMENTS'].append(manufacturer_shipments_x1000)
        df_dict['TRAVEL_TIME'].append(avg_travel_time_work_16plus)
        df_dict['HOUSEHOLD_INCOME'].append(median_household_income)
        df_dict['INCOME'].append(per_capita_income_12mo)
        df_dict['POVERTY'].append(people_in_poverty)
        df_dict['FIRMS'].append(all_firms)
        df_dict['MEN_FIRM'].append(men_owned_firms)
        df_dict['FEM_FIRM'].append(women_owned_firms)
        df_dict['MINOR_FIRM'].append(minority_owned_firms)
        df_dict['NON_MINOR_FIRM'].append(non_minority_owned_firms)
        df_dict['VET_FIRM'].append(veteran_owned_firms)
        df_dict['NON_VET_FIRM'].append(non_veteran_owned_firms)
        df_dict['POP_AREA'].append(population_per_sq_mile)
        df_dict['AREA'].append(land_in_sq_miles)    
    except Exception as err:
        for key, value in df_dict.items():
            if key == 'CITY' or key == 'STATE' or key == 'PA':
                continue
            else:
                df_dict[key].append("NaN")
        if err.__class__.__name__ == "HTTPError":
            print(f"{city} page not found in census.")
        else:
            print(f"An unexpected error occurred processing census for {city}. Error: {err}")
    return None

# %% [markdown]
# ## Table of States and Cities in that State

# %%
top_cities = pd.read_csv('Top5000Population.csv')
states = pd.read_csv('data.csv')

# %%
top_cities.head()
# Out:
#            City Code Population
# 0     New York    NY  8,363,710
# 1  Los Angeles    CA  3,833,995
# 2      Chicago    IL  2,853,114
# 3      Houston    TX  2,242,193
# 4      Phoenix    AZ  1,567,924

# %%
top_cities['Population'] = top_cities['Population'].apply(lambda x: x.replace(",",""))

# %%
top_cities['Population'] = pd.to_numeric(top_cities['Population'])

# %%
top_cities = top_cities[top_cities['Population']>5000]

# %%
top_cities.tail()
# Out:
#               City Code  Population
# 4562  Summerville    GA        5010
# 4563       Tipton    IN        5006
# 4564         Ayden   NC        5005
# 4565      Chelsea    MI        5005
# 4566      Thatcher   AZ        5002

# %%
states.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
states['Cities'] = np.empty((len(states), 0)).tolist()

# %%
states.head()
# Out:
#         State  Abbrev Code Cities
# 0     Alabama    Ala.   AL     []
# 1      Alaska  Alaska   AK     []
# 2     Arizona   Ariz.   AZ     []
# 3    Arkansas    Ark.   AR     []
# 4  California  Calif.   CA     []

# %%
for state_index, state_row in states.iterrows():
    for city_index, city_row in top_cities.iterrows():
        if city_row['Code'] == state_row['Code']:
            state_row['Cities'].append(city_row['City'])

# %%
states.head()
# Out:
#         State  Abbrev Code                                             Cities
# 0     Alabama    Ala.   AL  [Birmingham , Montgomery , Mobile , Huntsville...
# 1      Alaska  Alaska   AK  [Anchorage, Fairbanks , Juneau, Wasilla , Sitk...
# 2     Arizona   Ariz.   AZ  [Phoenix , Tucson , Mesa , Glendale , Chandler...
# 3    Arkansas    Ark.   AR  [Little Rock , Fort Smith , Fayetteville , Spr...
# 4  California  Calif.   CA  [Los Angeles , San Diego , San Jose , San Fran...

# %% [markdown]
# ## Table with Collected Data

# %%
#dictionary to track created threads
request_dict = {}
# bop = False

ccount = 4_565 # 4566 cities with a population > 5000
scount = 51 # 50 states
for state_index, state_row in states.iterrows():
#     if bop:
#         break
    state = state_row['State']
    for city in state_row['Cities']:
#         if ccount < 4000:
#             bop = True
#             break
        #create a thread to call collect_city_data with city and state as params. 
        request_dict[city] = threading.Thread(target=collect_city_data, args=(city, state))
        #start the newly made thread and move on to the next city
        request_dict[city].start()
        ccount -= 1
        print(f"{city} is done, {ccount} more to go!")
        time.sleep(0.1)
    scount -= 1
    print(f"{state} is done, {scount} more to go!")
# Out:
# Birmingham  is done, 4564 more to go!
# Montgomery  is done, 4563 more to go!
# Mobile  is done, 4562 more to go!
# Huntsville  is done, 4561 more to go!
# Tuscaloosa  is done, 4560 more to go!
# Hoover  is done, 4559 more to go!
# Dothan  is done, 4558 more to go!
# Auburn  is done, 4557 more to go!
# Decatur  is done, 4556 more to go!
# Madison  is done, 4555 more to go!
# Florence  is done, 4554 more to go!
# Gadsden  is done, 4553 more to go!
# Prattville  is done, 4552 more to go!
# Phenix City  is done, 4551 more to go!
# Vestavia Hills  is done, 4550 more to go!
# Alabaster  is done, 4549 more to go!
# Bessemer  is done, 4548 more to go!
# Prichard  is done, 4547 more to go!
# Opelika  is done, 4546 more to go!
# Enterprise  is done, 4545 more to go!
# Homewood  is done, 4544 more to go!
# Athens  is done, 4543 more to go!
# Anniston  is done, 4542 more to go!
# Northport  is done, 4541 more to go!
# Pelham  is done, 4540 more to go!
# Mountain Brook  is done, 4539 more to go!
# Oxford  is done, 4538 more to go!
# Albertville  is done, 4537 more to go!
# Daphne  is done, 4536 more to go!
# Trussville  is done, 4535 more to go!
# Selma  is done, 4534 more to go!
# Fairhope  is done, 4533 more to go!
# Talladega  is done, 4532 more to go!
# Millbrook  is done, 4531 more to go!
# Hueytown  is done, 4530 more to go!
# Center Point  is done, 4529 more to go!
# Cullman  is done, 4528 more to go!
# Troy  is done, 4527 more to go!
# Alexander City  is done, 4526 more to go!
# Scottsboro  is done, 4525 more to go!
# Ozark  is done, 4524 more to go!
# Helena  is done, 4523 more to go!
# Eufaula  is done, 4522 more to go!
# Jasper  is done, 4521 more to go!
# Fort Payne  is done, 4520 more to go!
# Hartselle  is done, 4519 more to go!
# Foley  is done, 4518 more to go!
# Gardendale  is done, 4517 more to go!
# Moody  is done, 4516 more to go!
# Muscle Shoals  is done, 4515 more to go!
# Saraland  is done, 4514 more to go!
# Sylacauga  is done, 4513 more to go!
# Pell City  is done, 4512 more to go!
# Tuskegee  is done, 4511 more to go!
# Fairfield  is done, 4510 more to go!
# Leeds  is done, 4509 more to go!
# Calera  is done, 4508 more to go!
# Pleasant Grove  is done, 4507 more to go!
# Gulf Shores  is done, 4506 more to go!
# Jacksonville  is done, 4505 more to go!
# Valley  is done, 4504 more to go!
# Irondale  is done, 4503 more to go!
# Rainbow City  is done, 4502 more to go!
# Sheffield  is done, 4501 more to go!
# Andalusia  is done, 4500 more to go!
# Russellville  is done, 4499 more to go!
# Clanton  is done, 4498 more to go!
# Guntersville  is done, 4497 more to go!
# Southside  is done, 4496 more to go!
# Boaz  is done, 4495 more to go!
# Clay  is done, 4494 more to go!
# Tuscumbia  is done, 4493 more to go!
# Bay Minette  is done, 4492 more to go!
# Arab  is done, 4491 more to go!
# Wetumpka  is done, 4490 more to go!
# Atmore  is done, 4489 more to go!
# Demopolis  is done, 4488 more to go!
# Lanett  is done, 4487 more to go!
# Oneonta  is done, 4486 more to go!
# Greenville  is done, 4485 more to go!
# Fultondale  is done, 4484 more to go!
# Pinson  is done, 4483 more to go!
# Roanoke  is done, 4482 more to go!
# Opp  is done, 4481 more to go!
# Attalla  is done, 4480 more to go!
# Tarrant  is done, 4479 more to go!
# Hamilton  is done, 4478 more to go!
# Monroeville  is done, 4477 more to go!
# Orange Beach  is done, 4476 more to go!
# Montevallo  is done, 4475 more to go!
# Satsuma  is done, 4474 more to go!
# Chickasaw  is done, 4473 more to go!
# Lincoln  is done, 4472 more to go!
# Spanish Fort  is done, 4471 more to go!
# Glencoe  is done, 4470 more to go!
# Brewton  is done, 4469 more to go!
# Midfield  is done, 4468 more to go!
# Tallassee  is done, 4467 more to go!
# Jackson  is done, 4466 more to go!
# Alabama is done, 50 more to go!
# Anchorage is done, 4465 more to go!
# Fairbanks  is done, 4464 more to go!
# Juneau is done, 4463 more to go!
# Wasilla  is done, 4462 more to go!
# Sitka  is done, 4461 more to go!
# Palmer  is done, 4460 more to go!
# Kenai  is done, 4459 more to go!
# Ketchikan  is done, 4458 more to go!
# Bethel  is done, 4457 more to go!
# Kodiak  is done, 4456 more to go!
# An unexpected error occurred processing census for Anchorage. Error: City Not Found
# Homer  is done, 4455 more to go!
# Alaska is done, 49 more to go!
# Phoenix  is done, 4454 more to go!
# Tucson  is done, 4453 more to go!An unexpected error occurred processing census for Juneau. Error: City Not Found
#
# Mesa  is done, 4452 more to go!
# An unexpected error occurred processing census for Tallassee . Error: City Not Found
# An unexpected error occurred processing census for Jackson . Error: City Not Found
# An unexpected error occurred processing census for Sitka . Error: City Not Found
# Glendale  is done, 4451 more to go!
# Chandler  is done, 4450 more to go!
# Scottsdale  is done, 4449 more to go!
# Gilbert is done, 4448 more to go!
# Tempe  is done, 4447 more to go!
# Peoria  is done, 4446 more to go!
# Surprise  is done, 4445 more to go!
# Yuma  is done, 4444 more to go!
# Avondale  is done, 4443 more to go!
# Flagstaff  is done, 4442 more to go!
# Goodyear  is done, 4441 more to go!
# Lake Havasu City  is done, 4440 more to go!
# Buckeye is done, 4439 more to go!
# Maricopa  is done, 4438 more to go!
# An unexpected error occurred processing census for Gilbert. Error: City Not Found
# Oro Valley is done, 4437 more to go!
# Sierra Vista  is done, 4436 more to go!
# Prescott  is done, 4435 more to go!
# Casa Grande  is done, 4434 more to go!
# Bullhead City  is done, 4433 more to go!
# Prescott Valley is done, 4432 more to go!
# Marana is done, 4431 more to go!
# Apache Junction  is done, 4430 more to go!
# Kingman  is done, 4429 more to go!
# Fountain Hills is done, 4428 more to go!
# San Luis  is done, 4427 more to go!
# El Mirage  is done, 4426 more to go!
# An unexpected error occurred processing census for Oro Valley. Error: City Not Found
# Queen Creek is done, 4425 more to go!
# Sahuarita is done, 4424 more to go!
# An unexpected error occurred processing census for Prescott Valley. Error: City Not FoundFlorence is done, 4423 more to go!
#
# An unexpected error occurred processing census for Marana. Error: City Not Found
# Nogales  is done, 4422 more to go!
# Douglas  is done, 4421 more to go!
# Payson is done, 4420 more to go!
# Paradise Valley is done, 4419 more to go!
# Eloy  is done, 4418 more to go!
# Somerton  is done, 4417 more to go!
# Show Low  is done, 4416 more to go!
# Sedona  is done, 4415 more to go!
# An unexpected error occurred processing census for Queen Creek. Error: City Not FoundCottonwood  is done, 4414 more to go!
#
# Chino Valley is done, 4413 more to go!An unexpected error occurred processing census for Fountain Hills. Error: City Not Found
#
# An unexpected error occurred processing census for Sahuarita. Error: City Not Found
# An unexpected error occurred processing census for Florence. Error: City Not Found
# Camp Verde is done, 4412 more to go!
# Coolidge  is done, 4411 more to go!An unexpected error occurred processing census for Paradise Valley. Error: City Not FoundAn unexpected error occurred processing census for Payson. Error: City Not Found
#
#
# Winslow  is done, 4410 more to go!
# Safford  is done, 4409 more to go!
# Tolleson  is done, 4408 more to go!
# Globe  is done, 4407 more to go!
# Page  is done, 4406 more to go!
# Wickenburg is done, 4405 more to go!
# An unexpected error occurred processing census for Camp Verde. Error: City Not Found
# South Tucson  is done, 4404 more to go!
# An unexpected error occurred processing census for Chino Valley. Error: City Not Found
# Bisbee  is done, 4403 more to go!
# Guadalupe is done, 4402 more to go!
# Snowflake is done, 4401 more to go!
# Cave Creek is done, 4400 more to go!
# Litchfield Park  is done, 4399 more to go!
# Holbrook  is done, 4398 more to go!
# Thatcher is done, 4397 more to go!
# Arizona is done, 48 more to go!
# Little Rock  is done, 4396 more to go!
# Fort Smith  is done, 4395 more to go!
# An unexpected error occurred processing census for Wickenburg. Error: City Not Found
# Fayetteville  is done, 4394 more to go!
# Springdale  is done, 4393 more to go!
# An unexpected error occurred processing census for Snowflake. Error: City Not Found
# Jonesboro  is done, 4392 more to go!
# An unexpected error occurred processing census for Guadalupe. Error: City Not Found
# North Little Rock  is done, 4391 more to go!
# An unexpected error occurred processing census for Cave Creek. Error: City Not Found
# Conway  is done, 4390 more to go!
# Rogers  is done, 4389 more to go!
# Pine Bluff  is done, 4388 more to go!
# Hot Springs  is done, 4387 more to go!
# Bentonville  is done, 4386 more to go!
# An unexpected error occurred processing census for Thatcher. Error: City Not Found
# Jacksonville  is done, 4385 more to go!
# Texarkana  is done, 4384 more to go!
# Benton  is done, 4383 more to go!
# Russellville  is done, 4382 more to go!
# West Memphis  is done, 4381 more to go!
# Paragould  is done, 4380 more to go!
# Sherwood  is done, 4379 more to go!
# Cabot  is done, 4378 more to go!
# Van Buren  is done, 4377 more to go!
# Searcy  is done, 4376 more to go!
# El Dorado  is done, 4375 more to go!
# Bella Vista is done, 4374 more to go!
# Maumelle  is done, 4373 more to go!
# Blytheville  is done, 4372 more to go!
# Bryant  is done, 4371 more to go!
# Siloam Springs  is done, 4370 more to go!
# Forrest City  is done, 4369 more to go!
# Harrison  is done, 4368 more to go!
# Mountain Home  is done, 4367 more to go!
# Marion  is done, 4366 more to go!
# Helena-West Helena  is done, 4365 more to go!
# Camden  is done, 4364 more to go!
# Arkadelphia  is done, 4363 more to go!
# Magnolia  is done, 4362 more to go!
# Hope  is done, 4361 more to go!
# Batesville  is done, 4360 more to go!
# Monticello  is done, 4359 more to go!
# Stuttgart  is done, 4358 more to go!
# Malvern  is done, 4357 more to go!
# An unexpected error occurred processing census for Helena-West Helena . Error: City Not Found
# Greenwood  is done, 4356 more to go!
# Centerton  is done, 4355 more to go!
# Clarksville  is done, 4354 more to go!
# Wynne  is done, 4353 more to go!
# Osceola  is done, 4352 more to go!
# Newport  is done, 4351 more to go!
# Heber Springs  is done, 4350 more to go!
# Lowell  is done, 4349 more to go!
# Beebe  is done, 4348 more to go!
# Trumann  is done, 4347 more to go!
# Pocahontas  is done, 4346 more to go!
# Morrilton  is done, 4345 more to go!
# Warren  is done, 4344 more to go!
# De Queen  is done, 4343 more to go!
# Mena  is done, 4342 more to go!
# Crossett  is done, 4341 more to go!
# Berryville  is done, 4340 more to go!
# White Hall  is done, 4339 more to go!
# Alma  is done, 4338 more to go!
# Arkansas is done, 47 more to go!
# Los Angeles  is done, 4337 more to go!
# San Diego  is done, 4336 more to go!
# San Jose  is done, 4335 more to go!
# San Francisco  is done, 4334 more to go!
# Fresno  is done, 4333 more to go!
# An unexpected error occurred processing census for Crossett . Error: City Not Found
# Sacramento  is done, 4332 more to go!
# Long Beach  is done, 4331 more to go!
# Oakland  is done, 4330 more to go!
# Santa Ana  is done, 4329 more to go!
# Anaheim  is done, 4328 more to go!
# Bakersfield  is done, 4327 more to go!
# Riverside  is done, 4326 more to go!
# Stockton  is done, 4325 more to go!
# Chula Vista  is done, 4324 more to go!
# Irvine  is done, 4323 more to go!
# Modesto  is done, 4322 more to go!
# Fremont  is done, 4321 more to go!
# San Bernardino  is done, 4320 more to go!
# Glendale  is done, 4319 more to go!
# Huntington Beach  is done, 4318 more to go!
# Moreno Valley  is done, 4317 more to go!
# Oxnard  is done, 4316 more to go!
# Fontana  is done, 4315 more to go!
# Ontario  is done, 4314 more to go!
# Rancho Cucamonga  is done, 4313 more to go!
# Oceanside  is done, 4312 more to go!
# Santa Clarita  is done, 4311 more to go!
# Garden Grove  is done, 4310 more to go!
# Santa Rosa  is done, 4309 more to go!
# Pomona  is done, 4308 more to go!
# Corona  is done, 4307 more to go!
# Lancaster  is done, 4306 more to go!
# Salinas  is done, 4305 more to go!
# Palmdale  is done, 4304 more to go!
# Pasadena  is done, 4303 more to go!
# Hayward  is done, 4302 more to go!
# Torrance  is done, 4301 more to go!
# Escondido  is done, 4300 more to go!
# Orange  is done, 4299 more to go!
# Elk Grove  is done, 4298 more to go!
# Sunnyvale  is done, 4297 more to go!
# Fullerton  is done, 4296 more to go!
# Thousand Oaks  is done, 4295 more to go!
# El Monte  is done, 4294 more to go!
# Concord  is done, 4293 more to go!
# Visalia  is done, 4292 more to go!
# Simi Valley  is done, 4291 more to go!
# Vallejo  is done, 4290 more to go!
# Inglewood  is done, 4289 more to go!
# Roseville  is done, 4288 more to go!
# Victorville  is done, 4287 more to go!
# Santa Clara  is done, 4286 more to go!
# Costa Mesa  is done, 4285 more to go!
# Downey  is done, 4284 more to go!
# West Covina  is done, 4283 more to go!
# Ventura is done, 4282 more to go!
# Fairfield  is done, 4281 more to go!
# Norwalk  is done, 4280 more to go!
# Burbank  is done, 4279 more to go!
# Richmond  is done, 4278 more to go!
# Daly City  is done, 4277 more to go!
# Berkeley  is done, 4276 more to go!
# Antioch  is done, 4275 more to go!
# Rialto  is done, 4274 more to go!
# Murrieta  is done, 4273 more to go!
# Temecula  is done, 4272 more to go!
# An unexpected error occurred processing census for Ventura. Error: City Not Found
# South Gate  is done, 4271 more to go!
# Carlsbad  is done, 4270 more to go!
# Mission Viejo  is done, 4269 more to go!
# Compton  is done, 4268 more to go!
# El Cajon  is done, 4267 more to go!
# Carson  is done, 4266 more to go!
# Clovis  is done, 4265 more to go!
# San Mateo  is done, 4264 more to go!
# Vacaville  is done, 4263 more to go!
# Vista  is done, 4262 more to go!
# Redding  is done, 4261 more to go!
# Westminster  is done, 4260 more to go!
# Santa Monica  is done, 4259 more to go!
# Santa Maria  is done, 4258 more to go!
# Santa Barbara  is done, 4257 more to go!
# Alhambra  is done, 4256 more to go!
# Hesperia  is done, 4255 more to go!
# Indio  is done, 4254 more to go!
# Citrus Heights  is done, 4253 more to go!
# Hawthorne  is done, 4252 more to go!
# Chico  is done, 4251 more to go!
# Chino  is done, 4250 more to go!
# Whittier  is done, 4249 more to go!
# Livermore  is done, 4248 more to go!
# Newport Beach  is done, 4247 more to go!
# Buena Park  is done, 4246 more to go!
# Tracy  is done, 4245 more to go!
# San Marcos  is done, 4244 more to go!
# Lakewood  is done, 4243 more to go!
# San Leandro  is done, 4242 more to go!
# Baldwin Park  is done, 4241 more to go!
# Merced  is done, 4240 more to go!
# Lake Forest  is done, 4239 more to go!
# Napa  is done, 4238 more to go!
# Redwood City  is done, 4237 more to go!
# Chino Hills  is done, 4236 more to go!
# Bellflower  is done, 4235 more to go!
# Union City  is done, 4234 more to go!
# Upland  is done, 4233 more to go!
# Tustin  is done, 4232 more to go!
# Mountain View  is done, 4231 more to go!
# Hemet  is done, 4230 more to go!
# Alameda  is done, 4229 more to go!
# Apple Valley is done, 4228 more to go!
# Lynwood  is done, 4227 more to go!
# Redlands  is done, 4226 more to go!
# Turlock  is done, 4225 more to go!
# Folsom  is done, 4224 more to go!
# Milpitas  is done, 4223 more to go!
# Redondo Beach  is done, 4222 more to go!
# Pleasanton  is done, 4221 more to go!
# Yorba Linda  is done, 4220 more to go!
# Manteca  is done, 4219 more to go!
# An unexpected error occurred processing census for Apple Valley. Error: City Not Found
# Laguna Niguel  is done, 4218 more to go!
# Pittsburg  is done, 4217 more to go!
# Walnut Creek  is done, 4216 more to go!
# Camarillo  is done, 4215 more to go!
# Pico Rivera  is done, 4214 more to go!
# Davis  is done, 4213 more to go!
# South San Francisco  is done, 4212 more to go!
# Rancho Cordova  is done, 4211 more to go!
# Montebello  is done, 4210 more to go!
# San Clemente  is done, 4209 more to go!
# Lodi  is done, 4208 more to go!
# Monterey Park  is done, 4207 more to go!
# Yuba City  is done, 4206 more to go!
# Huntington Park  is done, 4205 more to go!
# Encinitas  is done, 4204 more to go!
# Palo Alto  is done, 4203 more to go!
# La Habra  is done, 4202 more to go!
# National City  is done, 4201 more to go!
# Gardena  is done, 4200 more to go!
# Diamond Bar  is done, 4199 more to go!
# Madera  is done, 4198 more to go!
# Tulare  is done, 4197 more to go!
# Arcadia  is done, 4196 more to go!
# Santa Cruz  is done, 4195 more to go!
# Perris  is done, 4194 more to go!
# San Rafael  is done, 4193 more to go!
# Fountain Valley  is done, 4192 more to go!
# Paramount  is done, 4191 more to go!
# La Mesa  is done, 4190 more to go!
# Petaluma  is done, 4189 more to go!
# Woodland  is done, 4188 more to go!
# Rosemead  is done, 4187 more to go!
# Santee  is done, 4186 more to go!
# Cupertino  is done, 4185 more to go!
# Delano  is done, 4184 more to go!
# Rocklin  is done, 4183 more to go!
# Novato  is done, 4182 more to go!
# Cathedral City  is done, 4181 more to go!
# Porterville  is done, 4180 more to go!
# Cerritos  is done, 4179 more to go!
# Highland  is done, 4178 more to go!
# Lake Elsinore  is done, 4177 more to go!
# Palm Desert  is done, 4176 more to go!
# Colton  is done, 4175 more to go!
# Watsonville  is done, 4174 more to go!
# Hanford  is done, 4173 more to go!
# Gilroy  is done, 4172 more to go!
# La Mirada  is done, 4171 more to go!
# Yucaipa  is done, 4170 more to go!
# Placentia  is done, 4169 more to go!
# Rancho Santa Margarita  is done, 4168 more to go!
# Brentwood  is done, 4167 more to go!
# Glendora  is done, 4166 more to go!
# San Ramon  is done, 4165 more to go!
# Poway  is done, 4164 more to go!
# Palm Springs  is done, 4163 more to go!
# West Sacramento  is done, 4162 more to go!
# Cypress  is done, 4161 more to go!
# Covina  is done, 4160 more to go!
# Azusa  is done, 4159 more to go!
# Bell Gardens  is done, 4158 more to go!
# Dublin  is done, 4157 more to go!
# La Quinta  is done, 4156 more to go!
# San Luis Obispo  is done, 4155 more to go!
# Lincoln  is done, 4154 more to go!
# Ceres  is done, 4153 more to go!
# Newark  is done, 4152 more to go!
# Aliso Viejo  is done, 4151 more to go!
# Danville is done, 4150 more to go!
# Rancho Palos Verdes  is done, 4149 more to go!
# Lompoc  is done, 4148 more to go!
# La Puente  is done, 4147 more to go!
# Rohnert Park  is done, 4146 more to go!
# San Gabriel  is done, 4145 more to go!
# An unexpected error occurred processing census for Danville. Error: City Not Found
# San Bruno  is done, 4144 more to go!
# El Centro  is done, 4143 more to go!
# Coachella  is done, 4142 more to go!
# Campbell  is done, 4141 more to go!
# Culver City  is done, 4140 more to go!
# Calexico  is done, 4139 more to go!
# Temple City  is done, 4138 more to go!
# Brea  is done, 4137 more to go!
# Morgan Hill  is done, 4136 more to go!
# San Jacinto  is done, 4135 more to go!
# Pacifica  is done, 4134 more to go!
# Monrovia  is done, 4133 more to go!
# Stanton  is done, 4132 more to go!
# Bell  is done, 4131 more to go!
# Manhattan Beach  is done, 4130 more to go!
# Montclair  is done, 4129 more to go!
# Moorpark  is done, 4128 more to go!
# West Hollywood  is done, 4127 more to go!
# Dana Point  is done, 4126 more to go!
# Claremont  is done, 4125 more to go!
# Martinez  is done, 4124 more to go!
# San Dimas  is done, 4123 more to go!
# Los Banos  is done, 4122 more to go!
# Hollister  is done, 4121 more to go!
# San Juan Capistrano  is done, 4120 more to go!
# Beverly Hills  is done, 4119 more to go!
# Seaside  is done, 4118 more to go!
# La Verne  is done, 4117 more to go!
# East Palo Alto  is done, 4116 more to go!
# Twentynine Palms  is done, 4115 more to go!
# Pleasant Hill  is done, 4114 more to go!
# Beaumont  is done, 4113 more to go!
# Oakley  is done, 4112 more to go!
# Laguna Hills  is done, 4111 more to go!
# Lawndale  is done, 4110 more to go!
# Walnut  is done, 4109 more to go!
# San Pablo  is done, 4108 more to go!
# Saratoga  is done, 4107 more to go!
# Menlo Park  is done, 4106 more to go!
# Goleta  is done, 4105 more to go!
# Los Gatos is done, 4104 more to go!
# Foster City  is done, 4103 more to go!
# Banning  is done, 4102 more to go!
# Paso Robles is done, 4101 more to go!
# Santa Paula  is done, 4100 more to go!
# An unexpected error occurred processing census for Los Gatos. Error: City Not Found
# Adelanto  is done, 4099 more to go!
# Atascadero  is done, 4098 more to go!
# Los Altos  is done, 4097 more to go!
# Maywood  is done, 4096 more to go!
# Soledad  is done, 4095 more to go!
# Monterey  is done, 4094 more to go!
# Burlingame  is done, 4093 more to go!
# San Carlos  is done, 4092 more to go!
# Suisun City  is done, 4091 more to go!
# Norco  is done, 4090 more to go!
# Atwater  is done, 4089 more to go!
# An unexpected error occurred processing census for Paso Robles. Error: City Not Found
# Imperial Beach  is done, 4088 more to go!
# Paradise is done, 4087 more to go!
# Benicia  is done, 4086 more to go!
# Ridgecrest  is done, 4085 more to go!
# Sanger  is done, 4084 more to go!
# Windsor is done, 4083 more to go!
# Eureka  is done, 4082 more to go!
# An unexpected error occurred processing census for Paradise. Error: City Not Found
# Corcoran  is done, 4081 more to go!
# Lafayette  is done, 4080 more to go!
# Belmont  is done, 4079 more to go!
# Wasco  is done, 4078 more to go!
# Barstow  is done, 4077 more to go!
# Desert Hot Springs  is done, 4076 more to go!
# An unexpected error occurred processing census for Windsor. Error: City Not Found
# Hercules  is done, 4075 more to go!
# South Pasadena  is done, 4074 more to go!
# Cudahy  is done, 4073 more to go!
# Seal Beach  is done, 4072 more to go!
# Lemon Grove  is done, 4071 more to go!
# Galt  is done, 4070 more to go!
# Laguna Beach  is done, 4069 more to go!
# Lemoore  is done, 4068 more to go!
# San Fernando  is done, 4067 more to go!
# Reedley  is done, 4066 more to go!
# South Lake Tahoe  is done, 4065 more to go!
# Selma  is done, 4064 more to go!
# Brawley  is done, 4063 more to go!
# Coronado  is done, 4062 more to go!
# Agoura Hills  is done, 4061 more to go!
# El Cerrito  is done, 4060 more to go!
# Calabasas  is done, 4059 more to go!
# Duarte  is done, 4058 more to go!
# Blythe  is done, 4057 more to go!
# Loma Linda  is done, 4056 more to go!
# Port Hueneme  is done, 4055 more to go!
# South El Monte  is done, 4054 more to go!
# Millbrae  is done, 4053 more to go!
# La Canada Flintridge  is done, 4052 more to go!
# Riverbank  is done, 4051 more to go!
# Yucca Valley is done, 4050 more to go!
# Dinuba  is done, 4049 more to go!
# Oakdale  is done, 4048 more to go!
# Lomita  is done, 4047 more to go!
# Hermosa Beach  is done, 4046 more to go!
# Chowchilla  is done, 4045 more to go!An unexpected error occurred processing census for Yucca Valley. Error: City Not Found
#
# Patterson  is done, 4044 more to go!
# Coalinga  is done, 4043 more to go!
# Pinole  is done, 4042 more to go!
# Orinda  is done, 4041 more to go!
# Laguna Woods  is done, 4040 more to go!
# Marina  is done, 4039 more to go!
# Dixon  is done, 4038 more to go!
# Susanville  is done, 4037 more to go!
# Lathrop  is done, 4036 more to go!
# Arroyo Grande  is done, 4035 more to go!
# Santa Fe Springs  is done, 4034 more to go!
# Avenal  is done, 4033 more to go!
# Moraga is done, 4032 more to go!
# Arcata  is done, 4031 more to go!
# Rancho Mirage  is done, 4030 more to go!
# American Canyon  is done, 4029 more to go!
# Artesia  is done, 4028 more to go!
# El Segundo  is done, 4027 more to go!An unexpected error occurred processing census for Moraga. Error: City Not Found
#
# Truckee is done, 4026 more to go!
# Albany  is done, 4025 more to go!
# Shafter  is done, 4024 more to go!
# La Palma  is done, 4023 more to go!
# Hawaiian Gardens  is done, 4022 more to go!
# Greenfield  is done, 4021 more to go!
# An unexpected error occurred processing census for Truckee. Error: City Not Found
# Arvin  is done, 4020 more to go!
# Fillmore  is done, 4019 more to go!
# Clearlake  is done, 4018 more to go!
# Ukiah  is done, 4017 more to go!
# Oroville  is done, 4016 more to go!
# Pacific Grove  is done, 4015 more to go!
# California City  is done, 4014 more to go!
# Ripon  is done, 4013 more to go!
# Red Bluff  is done, 4012 more to go!
# Carpinteria  is done, 4011 more to go!
# Imperial  is done, 4010 more to go!
# Palos Verdes Estates  is done, 4009 more to go!
# Commerce  is done, 4008 more to go!
# Livingston  is done, 4007 more to go!
# Parlier  is done, 4006 more to go!
# Mill Valley  is done, 4005 more to go!
# Auburn  is done, 4004 more to go!
# Grover Beach  is done, 4003 more to go!
# Malibu  is done, 4002 more to go!
# Solana Beach  is done, 4001 more to go!
# San Marino  is done, 4000 more to go!
# Kerman  is done, 3999 more to go!
# Half Moon Bay  is done, 3998 more to go!
# Grass Valley  is done, 3997 more to go!
# Grand Terrace  is done, 3996 more to go!
# McFarland  is done, 3995 more to go!
# San Anselmo is done, 3994 more to go!
# Tehachapi  is done, 3993 more to go!
# Marysville  is done, 3992 more to go!
# Larkspur  is done, 3991 more to go!
# Los Alamitos  is done, 3990 more to go!
# King City  is done, 3989 more to go!An unexpected error occurred processing census for San Anselmo. Error: City Not Found
#
# Fortuna  is done, 3988 more to go!
# Clayton  is done, 3987 more to go!
# Canyon Lake  is done, 3986 more to go!
# Scotts Valley  is done, 3985 more to go!
# Kingsburg  is done, 3984 more to go!
# Healdsburg  is done, 3983 more to go!
# Signal Hill  is done, 3982 more to go!
# Hillsborough is done, 3981 more to go!
# Sierra Madre  is done, 3980 more to go!
# Orange Cove  is done, 3979 more to go!
# Lindsay  is done, 3978 more to go!
# Anderson  is done, 3977 more to go!
# Piedmont  is done, 3976 more to go!
# An unexpected error occurred processing census for Hillsborough. Error: City Not Found
# Mendota  is done, 3975 more to go!
# Morro Bay  is done, 3974 more to go!
# Newman  is done, 3973 more to go!
# Shasta Lake  is done, 3972 more to go!
# Farmersville  is done, 3971 more to go!
# Placerville  is done, 3970 more to go!
# Exeter  is done, 3969 more to go!
# Sonoma  is done, 3968 more to go!
# Capitola  is done, 3967 more to go!
# Emeryville  is done, 3966 more to go!
# Corte Madera is done, 3965 more to go!
# Taft  is done, 3964 more to go!
# Waterford  is done, 3963 more to go!
# Tiburon is done, 3962 more to go!
# Los Altos Hills is done, 3961 more to go!
# Pismo Beach  is done, 3960 more to go!
# Gonzales  is done, 3959 more to go!
# Westlake Village  is done, 3958 more to go!
# Live Oak  is done, 3957 more to go!
# Cloverdale  is done, 3956 more to go!
# Rolling Hills Estates  is done, 3955 more to go!
# Crescent City  is done, 3954 more to go!
# Rio Vista  is done, 3953 more to go!
# Ojai  is done, 3952 more to go!
# An unexpected error occurred processing census for Corte Madera. Error: City Not Found
# Huron  is done, 3951 more to go!
# An unexpected error occurred processing census for Los Altos Hills. Error: City Not FoundCalipatria  is done, 3950 more to go!
#
# An unexpected error occurred processing census for Tiburon. Error: City Not Found
# Sebastopol  is done, 3949 more to go!
# Ione  is done, 3948 more to go!
# Calimesa  is done, 3947 more to go!
# Woodlake  is done, 3946 more to go!
# Atherton is done, 3945 more to go!
# Mammoth Lakes is done, 3944 more to go!
# Yreka  is done, 3943 more to go!
# Escalon  is done, 3942 more to go!
# Corning  is done, 3941 more to go!
# Orland  is done, 3940 more to go!
# Cotati  is done, 3939 more to go!
# Sausalito  is done, 3938 more to go!
# An unexpected error occurred processing census for Mammoth Lakes. Error: City Not Found
# An unexpected error occurred processing census for Atherton. Error: City Not Found
# Fairfax is done, 3937 more to go!
# Winters  is done, 3936 more to go!
# Firebaugh  is done, 3935 more to go!
# Loomis is done, 3934 more to go!
# Fort Bragg  is done, 3933 more to go!
# Guadalupe  is done, 3932 more to go!
# Gridley  is done, 3931 more to go!
# Hughson  is done, 3930 more to go!
# Willows  is done, 3929 more to go!
# An unexpected error occurred processing census for Fairfax. Error: City Not Found
# Big Bear Lake  is done, 3928 more to go!
# An unexpected error occurred processing census for Loomis. Error: City Not Found
# Villa Park  is done, 3927 more to go!
# La Habra Heights  is done, 3926 more to go!
# Colusa  is done, 3925 more to go!
# St. Helena  is done, 3924 more to go!
# Woodside is done, 3923 more to go!
# Fowler  is done, 3922 more to go!
# Holtville  is done, 3921 more to go!
# Needles  is done, 3920 more to go!
# Calistoga  is done, 3919 more to go!
# An unexpected error occurred processing census for St. Helena . Error: City Not FoundIndian Wells  is done, 3918 more to go!An unexpected error occurred processing census for Woodside. Error: City Not Found
#
#
# Solvang  is done, 3917 more to go!
# Lakeport  is done, 3916 more to go!
# Gustine  is done, 3915 more to go!
# California is done, 46 more to go!
# Denver  is done, 3914 more to go!
# Colorado Springs  is done, 3913 more to go!
# Aurora  is done, 3912 more to go!
# An unexpected error occurred processing census for Needles . Error: City Not Found
# Lakewood  is done, 3911 more to go!
# Fort Collins  is done, 3910 more to go!
# An unexpected error occurred processing census for Lakeport . Error: City Not Found
# Thornton  is done, 3909 more to go!
# Arvada  is done, 3908 more to go!
# Westminster  is done, 3907 more to go!
# Pueblo  is done, 3906 more to go!
# Centennial  is done, 3905 more to go!
# Boulder  is done, 3904 more to go!
# Greeley  is done, 3903 more to go!
# Longmont  is done, 3902 more to go!
# Loveland  is done, 3901 more to go!
# Broomfield  is done, 3900 more to go!
# Grand Junction  is done, 3899 more to go!
# Castle Rock is done, 3898 more to go!
# Parker is done, 3897 more to go!
# Commerce City  is done, 3896 more to go!
# Littleton  is done, 3895 more to go!
# Northglenn  is done, 3894 more to go!
# Englewood  is done, 3893 more to go!
# Brighton  is done, 3892 more to go!
# Wheat Ridge  is done, 3891 more to go!
# An unexpected error occurred processing census for Castle Rock. Error: City Not Found
# Lafayette  is done, 3890 more to go!
# An unexpected error occurred processing census for Parker. Error: City Not Found
# Fountain  is done, 3889 more to go!
# Louisville  is done, 3888 more to go!
# Evans  is done, 3887 more to go!
# Windsor is done, 3886 more to go!
# Montrose  is done, 3885 more to go!
# Golden  is done, 3884 more to go!
# Erie is done, 3883 more to go!
# Durango  is done, 3882 more to go!
# An unexpected error occurred processing census for Windsor. Error: City Not Found
# Canon City  is done, 3881 more to go!
# Greenwood Village  is done, 3880 more to go!
# Sterling  is done, 3879 more to go!
# Federal Heights  is done, 3878 more to go!
# Superior is done, 3877 more to go!
# An unexpected error occurred processing census for Erie. Error: City Not Found
# Fort Morgan  is done, 3876 more to go!
# Steamboat Springs  is done, 3875 more to go!
# Lone Tree  is done, 3874 more to go!
# Johnstown is done, 3873 more to go!
# Craig  is done, 3872 more to go!
# Rifle  is done, 3871 more to go!
# An unexpected error occurred processing census for Superior. Error: City Not Found
# Trinidad  is done, 3870 more to go!
# Glenwood Springs  is done, 3869 more to go!
# Delta  is done, 3868 more to go!
# Alamosa  is done, 3867 more to go!
# Cortez  is done, 3866 more to go!
# An unexpected error occurred processing census for Johnstown. Error: City Not Found
# Frederick is done, 3865 more to go!
# Firestone is done, 3864 more to go!
# Lamar  is done, 3863 more to go!
# Fort Lupton  is done, 3862 more to go!
# Fruita  is done, 3861 more to go!
# La Junta  is done, 3860 more to go!
# Avon is done, 3859 more to go!
# Woodland Park  is done, 3858 more to go!
# An unexpected error occurred processing census for Frederick. Error: City Not Found
# Estes Park is done, 3857 more to go!
# An unexpected error occurred processing census for Firestone. Error: City Not Found
# Cherry Hills Village  is done, 3856 more to go!
# Carbondale is done, 3855 more to go!
# Milliken is done, 3854 more to go!
# Gypsum is done, 3853 more to go!
# Aspen  is done, 3852 more to go!
# An unexpected error occurred processing census for Avon. Error: City Not Found
# Eagle is done, 3851 more to go!
# Gunnison  is done, 3850 more to go!
# An unexpected error occurred processing census for Estes Park. Error: City Not Found
# An unexpected error occurred processing census for Carbondale. Error: City Not Found
# Berthoud is done, 3849 more to go!
# An unexpected error occurred processing census for Milliken. Error: City Not Found
# Sheridan  is done, 3848 more to go!
# An unexpected error occurred processing census for Gypsum. Error: City Not Found
# Salida  is done, 3847 more to go!
# Brush  is done, 3846 more to go!
# Manitou Springs  is done, 3845 more to go!
# Edgewater  is done, 3844 more to go!
# An unexpected error occurred processing census for Eagle. Error: City Not FoundWellington is done, 3843 more to go!
#
# An unexpected error occurred processing census for Berthoud. Error: City Not Found
# Colorado is done, 45 more to go!
# Bridgeport  is done, 3842 more to go!
# Hartford  is done, 3841 more to go!
# New Haven  is done, 3840 more to go!
# Stamford  is done, 3839 more to go!
# Waterbury  is done, 3838 more to go!
# Norwalk  is done, 3837 more to go!
# Danbury  is done, 3836 more to go!
# New Britain  is done, 3835 more to go!
# An unexpected error occurred processing census for Wellington. Error: City Not Found
# Bristol  is done, 3834 more to go!
# Meriden  is done, 3833 more to go!
# Milford  is done, 3832 more to go!
# West Haven  is done, 3831 more to go!
# Middletown  is done, 3830 more to go!
# Shelton  is done, 3829 more to go!
# Norwich  is done, 3828 more to go!
# Torrington  is done, 3827 more to go!
# Naugatuck is done, 3826 more to go!An unexpected error occurred processing census for Milford . Error: City Not Found
#
# New London  is done, 3825 more to go!
# Ansonia  is done, 3824 more to go!
# Derby  is done, 3823 more to go!
# Groton  is done, 3822 more to go!
# Connecticut is done, 44 more to go!
# Wilmington  is done, 3821 more to go!
# Dover  is done, 3820 more to go!
# An unexpected error occurred processing census for Naugatuck. Error: City Not Found
# Newark  is done, 3819 more to go!
# Middletown is done, 3818 more to go!
# Smyrna is done, 3817 more to go!
# Milford  is done, 3816 more to go!
# Seaford  is done, 3815 more to go!
# Elsmere is done, 3814 more to go!
# Georgetown is done, 3813 more to go!
# Delaware is done, 43 more to go!
# Washington  is done, 3812 more to go!
# An unexpected error occurred processing census for Middletown. Error: City Not Found
# District of Columbia is done, 42 more to go!
# Jacksonville  is done, 3811 more to go!
# Miami  is done, 3810 more to go!
# Tampa  is done, 3809 more to go!
# An unexpected error occurred processing census for Elsmere. Error: City Not Found
# An unexpected error occurred processing census for Georgetown. Error: City Not Found
# St. Petersburg  is done, 3808 more to go!
# Orlando  is done, 3807 more to go!
# Hialeah  is done, 3806 more to go!
# Fort Lauderdale  is done, 3805 more to go!
# Tallahassee  is done, 3804 more to go!
# Cape Coral  is done, 3803 more to go!
# An unexpected error occurred processing census for St. Petersburg . Error: City Not FoundPort St. Lucie  is done, 3802 more to go!
#
# Pembroke Pines  is done, 3801 more to go!
# An unexpected error occurred processing census for Smyrna. Error: City Not Found
# Hollywood  is done, 3800 more to go!
# Coral Springs  is done, 3799 more to go!
# Gainesville  is done, 3798 more to go!
# Miami Gardens  is done, 3797 more to go!
# Miramar  is done, 3796 more to go!
# Clearwater  is done, 3795 more to go!
# An unexpected error occurred processing census for Port St. Lucie . Error: City Not Found
# Pompano Beach  is done, 3794 more to go!
# Palm Bay  is done, 3793 more to go!
# West Palm Beach  is done, 3792 more to go!
# Lakeland  is done, 3791 more to go!
# Davie is done, 3790 more to go!
# Sunrise  is done, 3789 more to go!
# Boca Raton  is done, 3788 more to go!
# Miami Beach  is done, 3787 more to go!
# Deltona  is done, 3786 more to go!
# Plantation  is done, 3785 more to go!
# Melbourne  is done, 3784 more to go!
# Deerfield Beach  is done, 3783 more to go!
# Largo  is done, 3782 more to go!
# An unexpected error occurred processing census for Davie. Error: City Not Found
# Palm Coast  is done, 3781 more to go!
# Boynton Beach  is done, 3780 more to go!
# Lauderhill  is done, 3779 more to go!
# Fort Myers  is done, 3778 more to go!
# Daytona Beach  is done, 3777 more to go!
# Delray Beach  is done, 3776 more to go!
# Weston  is done, 3775 more to go!
# Kissimmee  is done, 3774 more to go!
# Tamarac  is done, 3773 more to go!
# Homestead  is done, 3772 more to go!
# North Miami  is done, 3771 more to go!
# North Port  is done, 3770 more to go!
# Ocala  is done, 3769 more to go!
# Port Orange  is done, 3768 more to go!
# Wellington is done, 3767 more to go!
# Margate  is done, 3766 more to go!
# Pensacola  is done, 3765 more to go!
# Bradenton  is done, 3764 more to go!
# Sarasota  is done, 3763 more to go!
# An unexpected error occurred processing census for Wellington. Error: City Not Found
# Sanford  is done, 3762 more to go!
# Coconut Creek  is done, 3761 more to go!
# Palm Beach Gardens  is done, 3760 more to go!
# Jupiter is done, 3759 more to go!
# Pinellas Park  is done, 3758 more to go!
# Titusville  is done, 3757 more to go!
# Coral Gables  is done, 3756 more to go!
# Bonita Springs  is done, 3755 more to go!
# Oakland Park  is done, 3754 more to go!
# An unexpected error occurred processing census for Jupiter. Error: City Not Found
# North Lauderdale  is done, 3753 more to go!
# Fort Pierce  is done, 3752 more to go!
# Altamonte Springs  is done, 3751 more to go!
# Hallandale Beach  is done, 3750 more to go!
# North Miami Beach  is done, 3749 more to go!
# Ormond Beach  is done, 3748 more to go!
# Apopka  is done, 3747 more to go!
# Panama City  is done, 3746 more to go!
# Riviera Beach  is done, 3745 more to go!
# Dunedin  is done, 3744 more to go!
# Lake Worth  is done, 3743 more to go!
# Winter Haven  is done, 3742 more to go!
# Plant City  is done, 3741 more to go!
# Winter Springs  is done, 3740 more to go!
# Oviedo  is done, 3739 more to go!
# Ocoee  is done, 3738 more to go!
# Greenacres  is done, 3737 more to go!
# Lauderdale Lakes  is done, 3736 more to go!
# Royal Palm Beach is done, 3735 more to go!
# Cooper City  is done, 3734 more to go!
# Winter Garden  is done, 3733 more to go!
# Aventura  is done, 3732 more to go!
# Cutler Bay is done, 3731 more to go!
# St. Cloud  is done, 3730 more to go!
# Dania Beach  is done, 3729 more to go!
# Winter Park  is done, 3728 more to go!
# An unexpected error occurred processing census for Royal Palm Beach. Error: City Not Found
# DeLand  is done, 3727 more to go!
# Casselberry  is done, 3726 more to go!
# An unexpected error occurred processing census for Cutler Bay. Error: City Not FoundRockledge  is done, 3725 more to go!
#
# An unexpected error occurred processing census for St. Cloud . Error: City Not Found
# Parkland  is done, 3724 more to go!
# Doral  is done, 3723 more to go!
# Tarpon Springs  is done, 3722 more to go!
# New Smyrna Beach  is done, 3721 more to go!
# Palmetto Bay is done, 3720 more to go!
# Temple Terrace  is done, 3719 more to go!
# Key West  is done, 3718 more to go!
# Leesburg  is done, 3717 more to go!
# Miami Lakes is done, 3716 more to go!
# Jacksonville Beach  is done, 3715 more to go!
# Naples  is done, 3714 more to go!
# Edgewater  is done, 3713 more to go!
# An unexpected error occurred processing census for Palmetto Bay. Error: City Not Found
# Venice  is done, 3712 more to go!
# An unexpected error occurred processing census for Miami Lakes. Error: City Not Found
# Sebastian  is done, 3711 more to go!
# Hialeah Gardens  is done, 3710 more to go!
# Crestview  is done, 3709 more to go!
# Eustis  is done, 3708 more to go!
# Haines City  is done, 3707 more to go!
# Seminole  is done, 3706 more to go!
# Fort Walton Beach  is done, 3705 more to go!
# Pinecrest is done, 3704 more to go!
# New Port Richey  is done, 3703 more to go!
# Safety Harbor  is done, 3702 more to go!
# Vero Beach  is done, 3701 more to go!
# Bartow  is done, 3700 more to go!
# Belle Glade  is done, 3699 more to go!
# Cocoa  is done, 3698 more to go!
# Palm Springs is done, 3697 more to go!
# An unexpected error occurred processing census for Pinecrest. Error: City Not Found
# Punta Gorda  is done, 3696 more to go!
# Sunny Isles Beach  is done, 3695 more to go!
# DeBary  is done, 3694 more to go!
# Stuart  is done, 3693 more to go!
# Marco Island  is done, 3692 more to go!
# West Melbourne  is done, 3691 more to go!
# Opa-locka  is done, 3690 more to go!
# An unexpected error occurred processing census for Palm Springs. Error: City Not Found
# Lynn Haven  is done, 3689 more to go!
# Lake Mary  is done, 3688 more to go!
# Lady Lake is done, 3687 more to go!
# Maitland  is done, 3686 more to go!
# Panama City Beach  is done, 3685 more to go!
# Lake Wales  is done, 3684 more to go!
# West Park  is done, 3683 more to go!
# Auburndale  is done, 3682 more to go!An unexpected error occurred processing census for Opa-locka . Error: City Not Found
#
# Palmetto  is done, 3681 more to go!
# An unexpected error occurred processing census for Lady Lake. Error: City Not Found
# Callaway  is done, 3680 more to go!
# Tavares  is done, 3679 more to go!
# South Daytona  is done, 3678 more to go!
# Longwood  is done, 3677 more to go!
# Oldsmar  is done, 3676 more to go!
# Holly Hill  is done, 3675 more to go!
# Zephyrhills  is done, 3674 more to go!
# Atlantic Beach  is done, 3673 more to go!
# Clermont  is done, 3672 more to go!
# Sweetwater  is done, 3671 more to go!
# Mount Dora  is done, 3670 more to go!
# Wilton Manors  is done, 3669 more to go!
# Destin  is done, 3668 more to go!
# Miami Springs  is done, 3667 more to go!
# Lake City  is done, 3666 more to go!
# St. Augustine  is done, 3665 more to go!
# Gulfport  is done, 3664 more to go!
# Niceville  is done, 3663 more to go!
# North Palm Beach is done, 3662 more to go!
# Cocoa Beach  is done, 3661 more to go!
# Satellite Beach  is done, 3660 more to go!
# Fernandina Beach  is done, 3659 more to go!
# An unexpected error occurred processing census for St. Augustine . Error: City Not FoundLighthouse Point  is done, 3658 more to go!
#
# Palatka  is done, 3657 more to go!An unexpected error occurred processing census for North Palm Beach. Error: City Not Found
#
# Sebring  is done, 3656 more to go!
# South Miami  is done, 3655 more to go!
# Cape Canaveral  is done, 3654 more to go!
# Lantana is done, 3653 more to go!
# Florida City  is done, 3652 more to go!
# St. Pete Beach  is done, 3651 more to go!
# Orange City  is done, 3650 more to go!
# Key Biscayne is done, 3649 more to go!
# Miami Shores is done, 3648 more to go!
# An unexpected error occurred processing census for Lantana. Error: City Not Found
# Palm Beach is done, 3647 more to go!
# Marathon  is done, 3646 more to go!
# Alachua  is done, 3645 more to go!
# Orange Park is done, 3644 more to go!
# An unexpected error occurred processing census for St. Pete Beach . Error: City Not Found
# Avon Park  is done, 3643 more to go!
# An unexpected error occurred processing census for Key Biscayne. Error: City Not Found
# Minneola  is done, 3642 more to go!
# An unexpected error occurred processing census for Miami Shores. Error: City Not Found
# Springfield  is done, 3641 more to go!
# Lake Park is done, 3640 more to go!
# An unexpected error occurred processing census for Palm Beach. Error: City Not Found
# Milton  is done, 3639 more to go!
# An unexpected error occurred processing census for Orange Park. Error: City Not Found
# Indian Harbour Beach  is done, 3638 more to go!
# Brooksville  is done, 3637 more to go!
# North Bay Village  is done, 3636 more to go!
# Groveland  is done, 3635 more to go!
# An unexpected error occurred processing census for Lake Park. Error: City Not Found
# Treasure Island  is done, 3634 more to go!
# Longboat Key is done, 3633 more to go!
# Inverness  is done, 3632 more to go!
# Southwest Ranches is done, 3631 more to go!
# Dade City  is done, 3630 more to go!
# Live Oak  is done, 3629 more to go!
# Clewiston  is done, 3628 more to go!
# Quincy  is done, 3627 more to go!
# Perry  is done, 3626 more to go!
# Neptune Beach  is done, 3625 more to go!
# An unexpected error occurred processing census for Longboat Key. Error: City Not Found
# Arcadia  is done, 3624 more to go!An unexpected error occurred processing census for Southwest Ranches. Error: City Not Found
#
# Pahokee  is done, 3623 more to go!
# Gulf Breeze  is done, 3622 more to go!
# Green Cove Springs  is done, 3621 more to go!
# Belle Isle  is done, 3620 more to go!
# Fort Myers Beach is done, 3619 more to go!
# Islamorada, Village of Islands is done, 3618 more to go!
# Marianna  is done, 3617 more to go!
# St. Augustine Beach  is done, 3616 more to go!
# Macclenny  is done, 3615 more to go!
# Valparaiso  is done, 3614 more to go!
# An unexpected error occurred processing census for Fort Myers Beach. Error: City Not FoundOkeechobee  is done, 3613 more to go!
#
# An unexpected error occurred processing census for Islamorada, Village of Islands. Error: City Not Found
# Starke  is done, 3612 more to go!
# An unexpected error occurred processing census for St. Augustine Beach . Error: City Not Found
# Flagler Beach  is done, 3611 more to go!
# Lauderdale-by-the-Sea is done, 3610 more to go!
# Fort Meade  is done, 3609 more to go!
# Tequesta is done, 3608 more to go!
# Sanibel  is done, 3607 more to go!
# Mascotte  is done, 3606 more to go!
# South Pasadena  is done, 3605 more to go!
# West Miami  is done, 3604 more to go!
# Indian Rocks Beach  is done, 3603 more to go!
# An unexpected error occurred processing census for Lauderdale-by-the-Sea. Error: City Not Found
# Daytona Beach Shores  is done, 3602 more to go!An unexpected error occurred processing census for Tequesta. Error: City Not Found
#
# Cedar Grove is done, 3601 more to go!
# Holmes Beach  is done, 3600 more to go!
# DeFuniak Springs  is done, 3599 more to go!
# Florida is done, 41 more to go!
# Atlanta  is done, 3598 more to go!
# Augusta is done, 3597 more to go!
# An unexpected error occurred processing census for Indian Rocks Beach . Error: City Not Found
# Columbus  is done, 3596 more to go!
# An unexpected error occurred processing census for Daytona Beach Shores . Error: City Not Found
# An unexpected error occurred processing census for Cedar Grove. Error: City Not Found
# Savannah  is done, 3595 more to go!
# An unexpected error occurred processing census for Holmes Beach . Error: City Not Found
# Athens is done, 3594 more to go!
# Macon  is done, 3593 more to go!
# Roswell  is done, 3592 more to go!
# An unexpected error occurred processing census for Augusta. Error: City Not Found
# Sandy Springs  is done, 3591 more to go!
# Albany  is done, 3590 more to go!
# An unexpected error occurred processing census for Athens. Error: City Not Found
# Marietta  is done, 3589 more to go!
# Warner Robins  is done, 3588 more to go!
# Johns Creek  is done, 3587 more to go!
# Alpharetta  is done, 3586 more to go!
# An unexpected error occurred processing census for Macon . Error: City Not Found
# Smyrna  is done, 3585 more to go!
# Valdosta  is done, 3584 more to go!
# East Point  is done, 3583 more to go!
# Rome  is done, 3582 more to go!
# Gainesville  is done, 3581 more to go!
# Peachtree City  is done, 3580 more to go!
# Dalton  is done, 3579 more to go!
# Kennesaw  is done, 3578 more to go!
# Douglasville  is done, 3577 more to go!
# Newnan  is done, 3576 more to go!
# Hinesville  is done, 3575 more to go!
# Lawrenceville  is done, 3574 more to go!
# LaGrange  is done, 3573 more to go!
# Statesboro  is done, 3572 more to go!
# Duluth  is done, 3571 more to go!
# Griffin  is done, 3570 more to go!
# Carrollton  is done, 3569 more to go!
# Woodstock  is done, 3568 more to go!
# Canton  is done, 3567 more to go!
# Forest Park  is done, 3566 more to go!
# Milledgeville  is done, 3565 more to go!
# Snellville  is done, 3564 more to go!
# College Park  is done, 3563 more to go!
# McDonough  is done, 3562 more to go!
# Acworth  is done, 3561 more to go!
# Thomasville  is done, 3560 more to go!
# Cartersville  is done, 3559 more to go!
# Decatur  is done, 3558 more to go!
# Dublin  is done, 3557 more to go!
# Tifton  is done, 3556 more to go!
# Sugar Hill  is done, 3555 more to go!
# Union City  is done, 3554 more to go!
# St. Marys  is done, 3553 more to go!
# Americus  is done, 3552 more to go!
# Suwanee  is done, 3551 more to go!
# Brunswick  is done, 3550 more to go!
# Powder Springs  is done, 3549 more to go!
# Moultrie  is done, 3548 more to go!
# Riverdale  is done, 3547 more to go!An unexpected error occurred processing census for St. Marys . Error: City Not Found
#
# Milton  is done, 3546 more to go!
# Fayetteville  is done, 3545 more to go!
# Covington  is done, 3544 more to go!
# Pooler  is done, 3543 more to go!
# Calhoun  is done, 3542 more to go!
# Waycross  is done, 3541 more to go!
# Stockbridge  is done, 3540 more to go!
# Winder  is done, 3539 more to go!
# Cusseta is done, 3538 more to go!
# Kingsland  is done, 3537 more to go!
# Conyers  is done, 3536 more to go!
# Monroe  is done, 3535 more to go!
# Perry  is done, 3534 more to go!
# Villa Rica  is done, 3533 more to go!
# An unexpected error occurred processing census for Cusseta. Error: City Not Found
# Bainbridge  is done, 3532 more to go!
# Buford  is done, 3531 more to go!
# ...
# An unexpected error occurred processing census for Warrenton. Error: City Not Found
# Smithfield is done, 299 more to go!
# Lexington  is done, 298 more to go!
# Galax  is done, 297 more to go!
# Buena Vista  is done, 296 more to go!
# An unexpected error occurred processing census for Abingdon. Error: City Not Found
# Bedford  is done, 295 more to go!
# An unexpected error occurred processing census for South Boston. Error: City Not Found
# Covington  is done, 294 more to go!
# An unexpected error occurred processing census for Farmville. Error: City Not Found
# Marion is done, 293 more to go!
# An unexpected error occurred processing census for Ashland. Error: City Not FoundBig Stone Gap is done, 292 more to go!
#
# An unexpected error occurred processing census for Smithfield. Error: City Not Found
# An unexpected error occurred processing census for Vinton. Error: City Not FoundEmporia  is done, 291 more to go!
#
# Bridgewater is done, 290 more to go!
# An unexpected error occurred processing census for Bedford . Error: City Not Found
# Bluefield is done, 289 more to go!
# Purcellville is done, 288 more to go!
# Virginia is done, 4 more to go!
# Seattle  is done, 287 more to go!
# Spokane  is done, 286 more to go!
# Tacoma  is done, 285 more to go!
# An unexpected error occurred processing census for Big Stone Gap. Error: City Not Found
# Vancouver  is done, 284 more to go!
# An unexpected error occurred processing census for Bridgewater. Error: City Not Found
# An unexpected error occurred processing census for Marion. Error: City Not Found
# Bellevue  is done, 283 more to go!
# An unexpected error occurred processing census for Purcellville. Error: City Not FoundAn unexpected error occurred processing census for Bluefield. Error: City Not Found
#
# Everett  is done, 282 more to go!
# Spokane Valley  is done, 281 more to go!
# Federal Way  is done, 280 more to go!
# Yakima  is done, 279 more to go!
# Kent  is done, 278 more to go!
# Bellingham  is done, 277 more to go!
# Kennewick  is done, 276 more to go!
# Renton  is done, 275 more to go!
# Lakewood  is done, 274 more to go!
# Auburn  is done, 273 more to go!
# Pasco  is done, 272 more to go!
# Shoreline  is done, 271 more to go!
# Redmond  is done, 270 more to go!
# Kirkland  is done, 269 more to go!
# Richland  is done, 268 more to go!
# Olympia  is done, 267 more to go!
# Lacey  is done, 266 more to go!
# Sammamish  is done, 265 more to go!
# Edmonds  is done, 264 more to go!
# Longview  is done, 263 more to go!
# Puyallup  is done, 262 more to go!
# Bremerton  is done, 261 more to go!
# Marysville  is done, 260 more to go!
# Lynnwood  is done, 259 more to go!
# Bothell  is done, 258 more to go!
# Mount Vernon  is done, 257 more to go!
# Burien  is done, 256 more to go!
# Walla Walla  is done, 255 more to go!
# University Place  is done, 254 more to go!
# Wenatchee  is done, 253 more to go!
# Des Moines  is done, 252 more to go!
# Pullman  is done, 251 more to go!
# SeaTac  is done, 250 more to go!
# Mercer Island  is done, 249 more to go!
# Issaquah  is done, 248 more to go!
# Oak Harbor  is done, 247 more to go!
# Bainbridge Island  is done, 246 more to go!
# Mukilteo  is done, 245 more to go!
# Kenmore  is done, 244 more to go!
# Maple Valley  is done, 243 more to go!
# Mountlake Terrace  is done, 242 more to go!
# Port Angeles  is done, 241 more to go!
# Moses Lake  is done, 240 more to go!
# Covington  is done, 239 more to go!
# Camas  is done, 238 more to go!
# Ellensburg  is done, 237 more to go!
# Tukwila  is done, 236 more to go!
# Monroe  is done, 235 more to go!
# Mill Creek  is done, 234 more to go!
# Battle Ground  is done, 233 more to go!
# Arlington  is done, 232 more to go!
# Bonney Lake  is done, 231 more to go!
# Anacortes  is done, 230 more to go!
# Aberdeen  is done, 229 more to go!
# Centralia  is done, 228 more to go!
# Sunnyside  is done, 227 more to go!
# Tumwater  is done, 226 more to go!
# Lake Stevens  is done, 225 more to go!
# Washougal  is done, 224 more to go!
# Lake Forest Park  is done, 223 more to go!
# East Wenatchee  is done, 222 more to go!
# Kelso  is done, 221 more to go!
# Lynden  is done, 220 more to go!
# Ferndale  is done, 219 more to go!
# Woodinville  is done, 218 more to go!
# Sedro-Woolley  is done, 217 more to go!
# West Richland  is done, 216 more to go!
# Enumclaw  is done, 215 more to go!
# Cheney  is done, 214 more to go!
# Newcastle  is done, 213 more to go!
# Edgewood  is done, 212 more to go!
# Sumner  is done, 211 more to go!
# An unexpected error occurred processing census for Sedro-Woolley . Error: City Not Found
# Grandview  is done, 210 more to go!
# Shelton  is done, 209 more to go!
# Toppenish  is done, 208 more to go!
# Port Townsend  is done, 207 more to go!
# College Place  is done, 206 more to go!
# Hoquiam  is done, 205 more to go!
# Snohomish  is done, 204 more to go!
# Burlington  is done, 203 more to go!
# Snoqualmie  is done, 202 more to go!
# Poulsbo  is done, 201 more to go!
# Fife  is done, 200 more to go!
# Port Orchard  is done, 199 more to go!
# Chehalis  is done, 198 more to go!
# Ephrata  is done, 197 more to go!
# Clarkston  is done, 196 more to go!
# Selah  is done, 195 more to go!
# Liberty Lake  is done, 194 more to go!
# Gig Harbor  is done, 193 more to go!
# DuPont  is done, 192 more to go!
# Milton  is done, 191 more to go!
# Othello  is done, 190 more to go!
# Brier  is done, 189 more to go!
# Normandy Park  is done, 188 more to go!
# Fircrest  is done, 187 more to go!
# Orting  is done, 186 more to go!
# Stanwood  is done, 185 more to go!
# Steilacoom is done, 184 more to go!
# Pacific  is done, 183 more to go!
# Duvall  is done, 182 more to go!
# Quincy  is done, 181 more to go!
# Sequim  is done, 180 more to go!
# Yelm  is done, 179 more to go!
# Union Gap  is done, 178 more to go!
# Airway Heights  is done, 177 more to go!
# Prosser  is done, 176 more to go!
# Ocean Shores  is done, 175 more to go!
# An unexpected error occurred processing census for Steilacoom. Error: City Not Found
# Washington is done, 3 more to go!
# Charleston  is done, 174 more to go!
# Huntington  is done, 173 more to go!
# Parkersburg  is done, 172 more to go!
# Morgantown  is done, 171 more to go!
# Wheeling  is done, 170 more to go!
# Fairmont  is done, 169 more to go!
# Weirton  is done, 168 more to go!
# Martinsburg  is done, 167 more to go!
# Beckley  is done, 166 more to go!
# Clarksburg  is done, 165 more to go!
# South Charleston  is done, 164 more to go!
# Bluefield  is done, 163 more to go!
# St. Albans  is done, 162 more to go!
# Vienna  is done, 161 more to go!
# Moundsville  is done, 160 more to go!
# Bridgeport  is done, 159 more to go!
# Dunbar  is done, 158 more to go!
# Oak Hill  is done, 157 more to go!
# Elkins  is done, 156 more to go!
# An unexpected error occurred processing census for St. Albans . Error: City Not Found
# Nitro  is done, 155 more to go!
# Hurricane  is done, 154 more to go!
# Princeton  is done, 153 more to go!
# New Martinsville  is done, 152 more to go!
# Buckhannon  is done, 151 more to go!
# Grafton  is done, 150 more to go!
# Keyser  is done, 149 more to go!
# West Virginia is done, 2 more to go!
# Milwaukee  is done, 148 more to go!
# Madison  is done, 147 more to go!
# Green Bay  is done, 146 more to go!
# Kenosha  is done, 145 more to go!
# Racine  is done, 144 more to go!
# Appleton  is done, 143 more to go!
# Waukesha  is done, 142 more to go!
# Eau Claire  is done, 141 more to go!
# An unexpected error occurred processing census for Keyser . Error: City Not Found
# Oshkosh  is done, 140 more to go!
# Janesville  is done, 139 more to go!
# West Allis  is done, 138 more to go!
# La Crosse  is done, 137 more to go!
# Sheboygan  is done, 136 more to go!
# Wauwatosa  is done, 135 more to go!
# Fond du Lac  is done, 134 more to go!
# Brookfield  is done, 133 more to go!
# New Berlin  is done, 132 more to go!
# Wausau  is done, 131 more to go!
# Beloit  is done, 130 more to go!
# Greenfield  is done, 129 more to go!
# Franklin  is done, 128 more to go!
# Menomonee Falls is done, 127 more to go!
# Oak Creek  is done, 126 more to go!
# Manitowoc  is done, 125 more to go!
# West Bend  is done, 124 more to go!
# Sun Prairie  is done, 123 more to go!
# Mount Pleasant is done, 122 more to go!
# Superior  is done, 121 more to go!
# An unexpected error occurred processing census for Menomonee Falls. Error: City Not Found
# Stevens Point  is done, 120 more to go!
# Neenah  is done, 119 more to go!
# De Pere  is done, 118 more to go!
# An unexpected error occurred processing census for Mount Pleasant. Error: City Not Found
# Caledonia is done, 117 more to go!
# Mequon  is done, 116 more to go!
# Fitchburg  is done, 115 more to go!
# Muskego  is done, 114 more to go!
# Watertown  is done, 113 more to go!
# South Milwaukee  is done, 112 more to go!
# Pleasant Prairie is done, 111 more to go!
# Germantown is done, 110 more to go!
# Cudahy  is done, 109 more to go!
# An unexpected error occurred processing census for Caledonia. Error: City Not Found
# Marshfield  is done, 108 more to go!
# Ashwaubenon is done, 107 more to go!
# An unexpected error occurred processing census for Pleasant Prairie. Error: City Not Found
# Wisconsin Rapids  is done, 106 more to go!
# Onalaska  is done, 105 more to go!
# Howard is done, 104 more to go!
# Menasha  is done, 103 more to go!
# Middleton  is done, 102 more to go!
# An unexpected error occurred processing census for Germantown. Error: City Not Found
# Menomonie  is done, 101 more to go!
# An unexpected error occurred processing census for Ashwaubenon. Error: City Not Found
# Kaukauna  is done, 100 more to go!
# An unexpected error occurred processing census for Howard. Error: City Not FoundBeaver Dam  is done, 99 more to go!
#
# Bellevue is done, 98 more to go!
# Allouez is done, 97 more to go!
# River Falls  is done, 96 more to go!
# Whitewater  is done, 95 more to go!
# Oconomowoc  is done, 94 more to go!
# An unexpected error occurred processing census for Bellevue. Error: City Not Found
# Greendale is done, 93 more to go!
# Hartford  is done, 92 more to go!
# An unexpected error occurred processing census for Allouez. Error: City Not Found
# Whitefish Bay is done, 91 more to go!
# Weston is done, 90 more to go!
# Shorewood is done, 89 more to go!
# An unexpected error occurred processing census for Greendale. Error: City Not FoundGlendale  is done, 88 more to go!
#
# Stoughton  is done, 87 more to go!
# Chippewa Falls  is done, 86 more to go!
# Pewaukee  is done, 85 more to go!
# Hudson  is done, 84 more to go!
# Fort Atkinson  is done, 83 more to go!
# Two Rivers  is done, 82 more to go!
# Plover is done, 81 more to go!
# An unexpected error occurred processing census for Whitefish Bay. Error: City Not Found
# An unexpected error occurred processing census for Weston. Error: City Not FoundAn unexpected error occurred processing census for Shorewood. Error: City Not Found
#
# Brown Deer is done, 80 more to go!
# Grafton is done, 79 more to go!
# Verona  is done, 78 more to go!
# Waunakee is done, 77 more to go!
# Baraboo  is done, 76 more to go!
# Port Washington  is done, 75 more to go!
# An unexpected error occurred processing census for Plover. Error: City Not FoundLittle Chute is done, 74 more to go!
#
# An unexpected error occurred processing census for Brown Deer. Error: City Not Found
# Cedarburg  is done, 73 more to go!An unexpected error occurred processing census for Grafton. Error: City Not Found
#
# Burlington  is done, 72 more to go!
# An unexpected error occurred processing census for Waunakee. Error: City Not Found
# Suamico is done, 71 more to go!
# Marinette  is done, 70 more to go!
# An unexpected error occurred processing census for Little Chute. Error: City Not Found
# Monroe  is done, 69 more to go!
# Waupun  is done, 68 more to go!
# An unexpected error occurred processing census for Suamico. Error: City Not Found
# Platteville  is done, 67 more to go!
# Sussex is done, 66 more to go!
# Portage  is done, 65 more to go!
# St. Francis  is done, 64 more to go!
# Merrill  is done, 63 more to go!
# Oregon is done, 62 more to go!
# An unexpected error occurred processing census for Sussex. Error: City Not Found
# Elkhorn  is done, 61 more to go!
# DeForest is done, 60 more to go!
# Sparta  is done, 59 more to go!
# Pewaukee is done, 58 more to go!
# An unexpected error occurred processing census for St. Francis . Error: City Not FoundSturgeon Bay  is done, 57 more to go!
#
# An unexpected error occurred processing census for Oregon. Error: City Not Found
# Hartland is done, 56 more to go!
# An unexpected error occurred processing census for DeForest. Error: City Not Found
# Reedsburg  is done, 55 more to go!
# Shawano  is done, 54 more to go!
# Tomah  is done, 53 more to go!
# Delavan  is done, 52 more to go!
# Holmen is done, 51 more to go!
# Lake Geneva  is done, 50 more to go!
# An unexpected error occurred processing census for Hartland. Error: City Not Found
# New Richmond  is done, 49 more to go!
# Rice Lake  is done, 48 more to go!
# Plymouth  is done, 47 more to go!
# Ashland  is done, 46 more to go!
# An unexpected error occurred processing census for Holmen. Error: City Not Found
# Antigo  is done, 45 more to go!
# Sheboygan Falls  is done, 44 more to go!
# Monona  is done, 43 more to go!
# Jefferson  is done, 42 more to go!
# McFarland is done, 41 more to go!
# Rhinelander  is done, 40 more to go!
# Hales Corners is done, 39 more to go!
# Ripon  is done, 38 more to go!
# Mukwonago is done, 37 more to go!An unexpected error occurred processing census for McFarland. Error: City Not Found
#
# Kronenwetter is done, 36 more to go!
# Sturtevant is done, 35 more to go!
# Fox Point is done, 34 more to go!
# Delafield  is done, 33 more to go!
# An unexpected error occurred processing census for Hales Corners. Error: City Not Found
# Jackson is done, 32 more to go!
# An unexpected error occurred processing census for Kronenwetter. Error: City Not Found
# An unexpected error occurred processing census for Mukwonago. Error: City Not Found
# Altoona  is done, 31 more to go!
# An unexpected error occurred processing census for Sturtevant. Error: City Not Found
# New London  is done, 30 more to go!
# Mount Horeb is done, 29 more to go!
# An unexpected error occurred processing census for Fox Point. Error: City Not Found
# Kimberly is done, 28 more to go!
# Cottage Grove is done, 27 more to go!
# An unexpected error occurred processing census for Jackson. Error: City Not FoundElm Grove is done, 26 more to go!
#
# Hobart is done, 25 more to go!
# An unexpected error occurred processing census for Kimberly. Error: City Not Found
# Prairie du Chien  is done, 24 more to go!An unexpected error occurred processing census for Mount Horeb. Error: City Not Found
#
# Waupaca  is done, 23 more to go!
# Twin Lakes is done, 22 more to go!
# Milton  is done, 21 more to go!
# Lake Mills  is done, 20 more to go!
# An unexpected error occurred processing census for Hobart. Error: City Not Found
# An unexpected error occurred processing census for Cottage Grove. Error: City Not Found
# Edgerton  is done, 19 more to go!
# An unexpected error occurred processing census for Elm Grove. Error: City Not Found
# North Fond du Lac is done, 18 more to go!
# An unexpected error occurred processing census for Twin Lakes. Error: City Not Found
# Columbus  is done, 17 more to go!
# Mayville  is done, 16 more to go!
# Richland Center  is done, 15 more to go!
# Rothschild is done, 14 more to go!
# Wisconsin is done, 1 more to go!
# Cheyenne  is done, 13 more to go!
# Casper  is done, 12 more to go!
# Laramie  is done, 11 more to go!An unexpected error occurred processing census for North Fond du Lac. Error: City Not Found
#
# An unexpected error occurred processing census for Mayville . Error: City Not Found
# Gillette  is done, 10 more to go!
# An unexpected error occurred processing census for Richland Center . Error: City Not Found
# An unexpected error occurred processing census for Rothschild. Error: City Not FoundRock Springs  is done, 9 more to go!
#
# Sheridan  is done, 8 more to go!
# Green River  is done, 7 more to go!
# Evanston  is done, 6 more to go!
# Riverton  is done, 5 more to go!
# Jackson is done, 4 more to go!
# Cody  is done, 3 more to go!
# Rawlins  is done, 2 more to go!
# Lander  is done, 1 more to go!
# Douglas  is done, 0 more to go!An unexpected error occurred processing census for Jackson. Error: City Not Found
#
# Powell  is done, -1 more to go!
# Torrington  is done, -2 more to go!
# Wyoming is done, 0 more to go!

# %%
city_df = pd.DataFrame(df_dict)
city_df.head()
# Out:
#           CITY    STATE       PA     POP UNDER_5 UNDER_18 65_OR_OVER FEMALE  \
# 0      Mobile   Alabama  liberal  189572     6.3     21.7       16.0   52.6
# 1  Birmingham   Alabama  liberal  209880     6.5     20.3       14.2   53.1
# 2  Montgomery   Alabama  liberal  198218     6.8     24.0       13.7   53.0
# 3  Tuscaloosa   Alabama  liberal  101113     5.9     18.8       11.7   52.4
# 4      Hoover   Alabama  liberal   85108     6.9     25.4       15.6   52.8
#
#   WHITE BLACK  ... POVERTY  FIRMS MEN_FIRM FEM_FIRM MINOR_FIRM NON_MINOR_FIRM  \
# 0  44.8  50.6  ...    22.0  20118     9703     8644       8808          10250
# 1  25.3  70.5  ...    27.2  20738    10318     8286      10605           8770
# 2  33.3  60.6  ...    21.9  18043     8879     7459       8793           8363
# 3  51.1  44.1  ...    24.2   6802     3374     2530       1953           4375
# 4  72.7  17.4  ...     6.7   7982     4402     2471       1371           6147
#
#   VET_FIRM NON_VET_FIRM POP_AREA    AREA
# 0     2275        16639   1402.6  139.11
# 1     2082        17113   1453.0  146.07
# 2     2352        14434   1289.5  159.57
# 3      670         5438   1501.9   60.23
# 4      831         6551   1730.6   47.16
#
# [5 rows x 47 columns]

# %%
city_df.tail()
# Out:
#              CITY    STATE            PA    POP UNDER_5 UNDER_18 65_OR_OVER  \
# 4562      Powell   Wyoming  conservative   6310     8.2     22.9       17.6
# 4563      Casper   Wyoming  conservative  57461     7.4     25.0       13.5
# 4564  Torrington   Wyoming  conservative   6701     6.7     21.1       20.2
# 4565        Cody   Wyoming  conservative   9828     6.3     22.1       20.0
# 4566    Riverton   Wyoming  conservative  10996     7.0     23.4       16.1
#
#      FEMALE WHITE BLACK  ... POVERTY FIRMS MEN_FIRM FEM_FIRM MINOR_FIRM  \
# 4562   51.6  91.6   0.3  ...    12.9   945      525      264         39
# 4563   50.5  94.0   1.8  ...     9.4  6059     3027     2002        353
# 4564   49.4  93.3   0.1  ...    12.9   906      459      325         36
# 4565   52.0  92.3   0.3  ...     7.8  1938      951      507         87
# 4566   48.8  80.5   1.1  ...    13.3  1181      545      396         86
#
#      NON_MINOR_FIRM VET_FIRM NON_VET_FIRM POP_AREA   AREA
# 4562            864      145          736   1487.4   4.25
# 4563           5316      721         4824   2056.1  26.90
# 4564            807      117          720   1405.9   4.62
# 4565           1751      285         1448    933.8  10.20
# 4566            987       48          999   1077.1   9.86
#
# [5 rows x 47 columns]

# %%
city_df.to_csv('city_stats.csv')
